# %%
#Question 1. 
from IPython.display import Image
Image("Screenshot 2024-08-29 194818.png")

# %%
#Question 2
# Parts of the tree that are repos are are the ones that say csci_1070 (Yours) and brandon.lin_csci_repo (Mine). 
# The local folders are the ones that say week_01, week_02, CSCI_1070_Course_Material, and warmup_8. There are also documents that 
# live under each folder which in this case is named 29.

# %%
#Question 3 
# Write a Python expression to iterate over the following dictionary: 
# months = ["January","February","March","April","May","June","July","August","September","October","November","December"] . 
# Have conditional logic to print "my birthday" if the month printed is your birth month. 
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]
birthday = "July"
for month in months:
    if month == birthday:
        print (birthday,": My Birthday")
    else:
        print(month)
# Out:
# January
# February
# March
# April
# May
# June
# July : my birthday
# August
# September
# October
# November
# December
